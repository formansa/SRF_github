# %% [markdown]
# ## Building a DataFrame from Name Files

# %%
import pandas as pd

def build_names_df(years):
    columns = ['name', 'sex', 'births','year']
    ldfs = []
    for year in years:
        file_name = 'names/yob'+str(year)+'.txt'
        year_frame = pd.read_csv(file_name, names=columns)
        year_frame['year'] = year
        ldfs.append(year_frame)
    return(pd.concat(ldfs,ignore_index = True))

years = range(1880,2017)
df_names = build_names_df(years)
print(df_names.head())
print(df_names.tail())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-3d0cee9ec491> in <module>()
#      12
#      13 years = range(1880,2017)
# ---> 14 df_names = build_names_df(years)
#      15 print(df_names.head())
#      16 print(df_names.tail())
#
# <ipython-input-1-3d0cee9ec491> in build_names_df(years)
#       6     for year in years:
#       7         file_name = 'names/yob'+str(year)+'.txt'
# ----> 8         year_frame = pd.read_csv(file_name, names=columns)
#       9         year_frame['year'] = year
#      10         ldfs.append(year_frame)
#
# /Users/Sam_I_Am/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /Users/Sam_I_Am/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# /Users/Sam_I_Am/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# /Users/Sam_I_Am/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# /Users/Sam_I_Am/anaconda/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# FileNotFoundError: File b'names/yob1880.txt' does not exist

# %% [markdown]
# ## Some statistics

# %%
# Total of males and females 
mf = df_names.groupby('sex').births.sum()
print('Number of males:   ',mf.loc['M'])
print('Number of females: ',mf.loc['F'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0c094759e2b8> in <module>()
#       1 # Total of males and females
# ----> 2 mf = df_names.groupby('sex').births.sum()
#       3 print('Number of males:   ',mf.loc['M'])
#       4 print('Number of females: ',mf.loc['F'])
#
# NameError: name 'df_names' is not defined

# %%
# Total of males and females per year
mfy = df_names.pivot_table(index='year',
                               columns='sex', values='births', aggfunc=sum)
print(mfy.head())
# Out:
# sex        F       M
# year
# 1880   90992  110491
# 1881   91953  100743
# 1882  107847  113686
# 1883  112318  104627
# 1884  129020  114443

# %%
import matplotlib.pyplot as plt
% matplotlib inline

mfy.plot()
